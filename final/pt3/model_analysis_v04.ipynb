# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
# %matplotlib inline
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.linear_model import LinearRegression

#additional libraries
from sklearn import ensemble
from sklearn import metrics
from sklearn.model_selection import cross_validate


# annoying warnings
import warnings
warnings.filterwarnings('ignore')

#additional libraries, Payman
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

from xgboost import XGBRegressor
import xgboost as xgb

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn import tree
import glob

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 100, "display.max_columns", 100): 
        display(df)

# %%
def oversample_extremes(data, low_val=42, low_weight=2, high_val=48, high_weight=2):
    '''
    A function that will create duplicate rows of specified rows in order to weight certain rows in machine learning training
    
    INPUTS:
    data: a pandas dataframe
    low_val: value of 'Quality' below which we will duplicate rows
    low_weight: integer of effective weight desired for low values
    high_val: value of 'Quality' above which we will duplicate rows
    high_weight: integer for effective weight desired for high values
    
    RETURNS:
    newdata: a pandas dataframe with duplicated rows according to the arguments passed
    
    NOTES:
    
    'low_weight' and 'high_weight' both need integer values and correspond to the effective weight of the sample compared
    to the rest of the data in the dataframe. For an example, a weight of 2 would mean creating 1 duplicate (so the
    row is now in the data twice), and a weight of 1 would return the same dataset (no additional duplicates created)
    
    Default cutoff values correspond to roughly anything outside the IQR
    '''
    # identify rows of interest
    low_df = data.loc[data['Quality'] < low_val]
    high_df = data.loc[data['Quality'] > high_val]
    
    newdata = data.copy()
    
    # loop to add on all the rows
    
    for i in range(low_weight-1): #pythonic indexing...
        newdata = newdata.append(low_df, ignore_index = True)
    for i in range(high_weight-1):
        newdata = newdata.append(high_df, ignore_index = True)
    
    return(newdata)

# %% [markdown]
# ### XGBRegressor

# %% [markdown]
# **Without sampling**

# %%
xgb_dict = {}
os.chdir("../p_data")
for file in glob.glob('*.csv'):
#     print('\nData:',file)
    df = pd.read_csv(file)
    train, val, test = np.split(df.sample(frac=1), 
                                [int(.6*len(df)), 
                                 int(.8*len(df))])
    
    y_train = train['Quality']
    train.drop(['Quality'], axis = 1, inplace = True)
    X_train = train
    
    y_val = val['Quality']
    val.drop(['Quality'], axis = 1, inplace = True)
    X_val = val
    
    y_test = test['Quality']
    test.drop(['Quality'], axis = 1, inplace = True)
    X_test = test

    xgb_ml = xgb.XGBRegressor(n_estimators=160, max_depth=15)
    

    xgb_fit = xgb_ml.fit(X_train, y_train)
    xgb_preds = xgb_fit.predict(X_val)
#     print(xgb_ml.feature_importances_)
    
    mae = mean_absolute_error(y_val, xgb_preds)
    mse = mean_squared_error(y_val, xgb_preds)
    r_squared = r2_score(y_val, xgb_preds)
    
    xgb_dict[str(file)] = {}
    xgb_dict[str(file)]['mae'] = mae
    xgb_dict[str(file)]['mse'] = mse
    xgb_dict[str(file)]['r_squared'] = r_squared
    xgb_dict[str(file)]['feat_imp'] = xgb_ml.feature_importances_
    
    
#     print("MAE: {:.{}f}".format(mae, 2))
#     print("MSE: {:.{}f}".format(mse, 2))
#     print("R-squared: {:.{}f}".format(r_squared, 2))

# %%
xgb_df = pd.DataFrame.from_dict(xgb_dict)

# %% [markdown]
# **With sampling**

# %%
xgb_s_dict = {}
os.chdir("../p_data")
for file in glob.glob('*.csv'):
#     print('\nData:',file)
    df = pd.read_csv(file)
    temp_train, val, test = np.split(df.sample(frac=1), 
                                [int(.6*len(df)), 
                                 int(.8*len(df))])
    
    y_val = val['Quality']
    val.drop(['Quality'], axis = 1, inplace = True)
    X_val = val

    y_test = test['Quality']
    test.drop(['Quality'], axis = 1, inplace = True)
    X_test = test
    
    for w in range(1,6,2):
#         print('Weight:',w)
        temp_df = oversample_extremes(temp_train, low_weight=w, high_weight = w)

        y_train = temp_df['Quality']
        temp_df.drop(['Quality'], axis = 1, inplace = True)
        X_train = temp_df

        xgb_ml = xgb.XGBRegressor(n_estimators=160, max_depth=15)
        
        xgb_fit = xgb_ml.fit(X_train, y_train)
        xgb_preds = xgb_fit.predict(X_val)
        
        mae = mean_absolute_error(y_val, xgb_preds)
        mse = mean_squared_error(y_val, xgb_preds)
        r_squared = r2_score(y_val, xgb_preds)
        
        xgb_s_dict[str(file) + '_w' + str(w)] = {}
        xgb_s_dict[str(file) + '_w' + str(w)]['mae'] = mae
        xgb_s_dict[str(file) + '_w' + str(w)]['mse'] = mse
        xgb_s_dict[str(file) + '_w' + str(w)]['r_squared'] = r_squared
        xgb_s_dict[str(file) + '_w' + str(w)]['feat_imp'] = xgb_ml.feature_importances_


#         print("MAE: {:.{}f}".format(mae, 2))
#         print("MSE: {:.{}f}".format(mse, 2))
#         print("R-squared: {:.{}f}".format(r_squared, 2))

# %%
xgb_s_df = pd.DataFrame.from_dict(xgb_s_dict)

# %%
xgb_summ = pd.concat([xgb_df.T, xgb_s_df.T])

# %%
xgb_summ['Model'] = 'XGB'

# %% [markdown]
# ### RandomForestRegressor

# %%
#get best hyper parameters for the model
# hyperparameters = {
#     'n_estimators': range(90, 201, 10),
#     'max_depth': range(2, 12, 2),
#     'min_samples_split' : range(2, 10, 2),
#     'min_samples_leaf' : list(range(1, 10, 1))
# #     'min_weight_fraction_leaf' : (0.0)
#                               }

# grid = GridSearchCV(base_model, param_grid=hyperparameters, n_jobs=-1)
# grid.fit(X_train, y_train)
# print('score = {}\nparams={}'.format(grid.best_score_, grid.best_params_))

# %% [markdown]
# **Without sampling**

# %%
rf_dict = {}
os.chdir("../p_data")
for file in glob.glob('*.csv'):
#     print('\nData:',file)
    df = pd.read_csv(file)
    train, val, test = np.split(df.sample(frac=1), 
                                [int(.6*len(df)), 
                                 int(.8*len(df))])
    
    y_train = train['Quality']
    train.drop(['Quality'], axis = 1, inplace = True)
    X_train = train
    
    y_val = val['Quality']
    val.drop(['Quality'], axis = 1, inplace = True)
    X_val = val
    
    y_test = test['Quality']
    test.drop(['Quality'], axis = 1, inplace = True)
    X_test = test
    
    rf_reg = RandomForestRegressor(n_jobs=5, n_estimators= 120, max_depth= 10,
                    min_samples_split = 9,min_samples_leaf = 4,
                    min_weight_fraction_leaf= 0.0)
    
    rf_fit = rf_reg.fit(X_train, y_train)
    rf_reg_preds = rf_fit.predict(X_val)
    
    mae = mean_absolute_error(y_val, rf_reg_preds)
    mse = mean_squared_error(y_val, rf_reg_preds)
    r_squared = r2_score(y_val, rf_reg_preds)
    
    rf_dict[str(file)] = {}
    rf_dict[str(file)]['mae'] = mae
    rf_dict[str(file)]['mse'] = mse
    rf_dict[str(file)]['r_squared'] = r_squared
    rf_dict[str(file)]['feat_imp'] = rf_reg.feature_importances_

# %%
rf_df = pd.DataFrame.from_dict(rf_dict)

# %% [markdown]
# **With sampling**

# %%
rf_s_dict = {}
os.chdir("../p_data")
for file in glob.glob('*.csv'):
#     print('\nData:',file)
    df = pd.read_csv(file)
    temp_train, val, test = np.split(df.sample(frac=1), 
                                [int(.6*len(df)), 
                                 int(.8*len(df))])
    
    y_val = val['Quality']
    val.drop(['Quality'], axis = 1, inplace = True)
    X_val = val

    y_test = test['Quality']
    test.drop(['Quality'], axis = 1, inplace = True)
    X_test = test
    
    for w in range(1,6,2):
#         print('Weight:',w)
        temp_df = oversample_extremes(temp_train, low_weight=w, high_weight = w)

        y_train = temp_df['Quality']
        temp_df.drop(['Quality'], axis = 1, inplace = True)
        X_train = temp_df

        rf_reg = RandomForestRegressor(n_jobs=5, n_estimators= 120, max_depth= 10,
                        min_samples_split = 9,min_samples_leaf = 4,
                        min_weight_fraction_leaf= 0.0)

        rf_fit = rf_reg.fit(X_train, y_train)
        rf_reg_preds = rf_fit.predict(X_val)
        
        mae = mean_absolute_error(y_val, rf_reg_preds)
        mse = mean_squared_error(y_val, rf_reg_preds)
        r_squared = r2_score(y_val, rf_reg_preds)
        
        rf_s_dict[str(file) + '_w' + str(w)] = {}
        rf_s_dict[str(file) + '_w' + str(w)]['mae'] = mae
        rf_s_dict[str(file) + '_w' + str(w)]['mse'] = mse
        rf_s_dict[str(file) + '_w' + str(w)]['r_squared'] = r_squared
        rf_s_dict[str(file) + '_w' + str(w)]['feat_imp'] = rf_reg.feature_importances_

# %%
rf_s_df = pd.DataFrame.from_dict(rf_s_dict)

# %%
rf_summ = pd.concat([rf_df.T, rf_s_df.T])

# %%
rf_summ['Model'] = 'RandomForest'

# %%
model_summ = pd.concat([xgb_summ, rf_summ])

# %%
model_summ
# Out:
#                                                                      feat_imp  \
# no_tempinc.csv              [0.010616321, 0.01124595, 0.7321606, 0.0095584...
# no_tempinc_minmax.csv       [0.0040060766, 0.0, 0.004586884, 0.87501675, 0...
# no_tempinc_standard.csv     [0.002098261, 0.0, 0.004272864, 0.9188961, 0.0...
# tempinc.csv                 [0.004522228, 0.005455211, 0.82258695, 0.00869...
# tempinc_minmax.csv          [0.0027495276, 0.0, 0.00253314, 0.9097434, 0.0...
# tempinc_standard.csv        [0.001598057, 0.0, 0.0026110376, 0.93779457, 0...
# no_tempinc.csv_w1           [0.007185624, 0.006700246, 0.8533451, 0.005470...
# no_tempinc.csv_w3           [0.0025024228, 0.0038228417, 0.93996364, 0.001...
# no_tempinc.csv_w5           [0.0014790962, 0.0026599183, 0.9485154, 0.0009...
# no_tempinc_minmax.csv_w1    [0.0035745816, 0.0, 0.0040917215, 0.9350306, 0...
# no_tempinc_minmax.csv_w3    [0.0044359653, 0.0, 0.0046973457, 0.9227859, 0...
# no_tempinc_minmax.csv_w5    [0.005682336, 0.0, 0.005929909, 0.91001, 0.002...
# no_tempinc_standard.csv_w1  [0.0023506477, 0.0, 0.0030747093, 0.9010628, 0...
# no_tempinc_standard.csv_w3  [0.0023448896, 0.0, 0.002684519, 0.8925107, 0....
# no_tempinc_standard.csv_w5  [0.0021580537, 0.0, 0.002546614, 0.8897561, 0....
# tempinc.csv_w1              [0.0075900466, 0.007901227, 0.7488843, 0.00734...
# tempinc.csv_w3              [0.0025797277, 0.0025970198, 0.9012106, 0.0033...
# tempinc.csv_w5              [0.0011364846, 0.0028603063, 0.9541996, 0.0022...
# tempinc_minmax.csv_w1       [0.004413662, 0.0, 0.004751469, 0.9123705, 0.0...
# tempinc_minmax.csv_w3       [0.004866778, 0.0, 0.0061931224, 0.8909109, 0....
# tempinc_minmax.csv_w5       [0.00435395, 0.0, 0.006284555, 0.87035006, 0.0...
# tempinc_standard.csv_w1     [0.003273646, 0.0, 0.0029930652, 0.9056725, 0....
# tempinc_standard.csv_w3     [0.003279502, 0.0, 0.0029794828, 0.9046678, 0....
# tempinc_standard.csv_w5     [0.002741754, 0.0, 0.0026369556, 0.896059, 0.0...
# no_tempinc.csv              [0.05355123442057005, 0.06843679016391348, 0.1...
# no_tempinc_minmax.csv       [0.04322643208376294, 0.03836253261671352, 0.0...
# no_tempinc_standard.csv     [0.030535894528414827, 0.03083623724014279, 0....
# tempinc.csv                 [0.039895780524267094, 0.08058323357366043, 0....
# tempinc_minmax.csv          [0.022897365284291933, 0.028533459585647545, 0...
# tempinc_standard.csv        [0.03007864570106209, 0.03209287312142463, 0.0...
# no_tempinc.csv_w1           [0.04529165319750909, 0.09796988122629229, 0.0...
# no_tempinc.csv_w3           [0.039650507391347886, 0.1335544420800936, 0.1...
# no_tempinc.csv_w5           [0.03987915830898582, 0.1430823449955169, 0.08...
# no_tempinc_minmax.csv_w1    [0.047481296610358936, 0.03891007692388185, 0....
# no_tempinc_minmax.csv_w3    [0.0487222664168777, 0.04821980686165269, 0.06...
# no_tempinc_minmax.csv_w5    [0.04284319623742259, 0.04506262317146338, 0.0...
# no_tempinc_standard.csv_w1  [0.02896578599553321, 0.027535279905785037, 0....
# no_tempinc_standard.csv_w3  [0.034409516668093186, 0.03300392975122114, 0....
# no_tempinc_standard.csv_w5  [0.03333652636459231, 0.034216883086092095, 0....
# tempinc.csv_w1              [0.06211789935281993, 0.05450461182465864, 0.0...
# tempinc.csv_w3              [0.07911495750478056, 0.05667097289151612, 0.1...
# tempinc.csv_w5              [0.08640134208072398, 0.060567478657367196, 0....
# tempinc_minmax.csv_w1       [0.03146586974664891, 0.031827204166816864, 0....
# tempinc_minmax.csv_w3       [0.03772003654643796, 0.038747950147682765, 0....
# tempinc_minmax.csv_w5       [0.040677857063344446, 0.04192120458573366, 0....
# tempinc_standard.csv_w1     [0.02994804844824547, 0.028969605012624636, 0....
# tempinc_standard.csv_w3     [0.04319988531232704, 0.04070706213567532, 0.0...
# tempinc_standard.csv_w5     [0.04843419534398834, 0.043000194886327545, 0....
#
#                                   mae         mse r_squared         Model
# no_tempinc.csv               0.614908     1.27309  0.675926           XGB
# no_tempinc_minmax.csv       0.0294134  0.00268545  0.630875           XGB
# no_tempinc_standard.csv       0.37335    0.378409   0.59606           XGB
# tempinc.csv                  0.655323     1.25939  0.687694           XGB
# tempinc_minmax.csv           0.028061  0.00177771  0.687364           XGB
# tempinc_standard.csv         0.318485    0.305168  0.693136           XGB
# no_tempinc.csv_w1            0.607769    0.975468  0.738696           XGB
# no_tempinc.csv_w3            0.668146     1.18457  0.682683           XGB
# no_tempinc.csv_w5            0.683214     1.24799  0.665694           XGB
# no_tempinc_minmax.csv_w1    0.0312823  0.00318844  0.475876           XGB
# no_tempinc_minmax.csv_w3     0.032836  0.00446178  0.266563           XGB
# no_tempinc_minmax.csv_w5    0.0330172  0.00487382  0.198831           XGB
# no_tempinc_standard.csv_w1   0.376982     0.42907   0.55927           XGB
# no_tempinc_standard.csv_w3   0.409119    0.666305  0.315587           XGB
# no_tempinc_standard.csv_w5   0.421731    0.767217  0.211934           XGB
# tempinc.csv_w1               0.672679     1.39695  0.675303           XGB
# tempinc.csv_w3               0.711012      1.5411  0.641797           XGB
# tempinc.csv_w5               0.733331     1.60846   0.62614           XGB
# tempinc_minmax.csv_w1       0.0285944  0.00215622  0.651132           XGB
# tempinc_minmax.csv_w3       0.0287068   0.0023313  0.622804           XGB
# tempinc_minmax.csv_w5       0.0294492  0.00223648  0.638146           XGB
# tempinc_standard.csv_w1       0.36674    0.399304  0.612084           XGB
# tempinc_standard.csv_w3       0.35501    0.458606  0.554473           XGB
# tempinc_standard.csv_w5      0.363797    0.477566  0.536054           XGB
# no_tempinc.csv               0.725192      1.2689  0.639824  RandomForest
# no_tempinc_minmax.csv       0.0323015  0.00217952  0.661565  RandomForest
# no_tempinc_standard.csv      0.361494     0.25033  0.711342  RandomForest
# tempinc.csv                  0.739957     1.16688  0.620966  RandomForest
# tempinc_minmax.csv          0.0317864  0.00251445  0.600354  RandomForest
# tempinc_standard.csv         0.394865    0.381709  0.600363  RandomForest
# no_tempinc.csv_w1            0.815191     1.74302  0.517908  RandomForest
# no_tempinc.csv_w3            0.859842     1.83966  0.491178  RandomForest
# no_tempinc.csv_w5            0.880001     1.85963  0.485655  RandomForest
# no_tempinc_minmax.csv_w1    0.0334954  0.00262365  0.595074  RandomForest
# no_tempinc_minmax.csv_w3    0.0324501  0.00251928  0.611181  RandomForest
# no_tempinc_minmax.csv_w5    0.0331648  0.00283798  0.561994  RandomForest
# no_tempinc_standard.csv_w1    0.40604    0.457309  0.573131  RandomForest
# no_tempinc_standard.csv_w3   0.383734    0.421223  0.606816  RandomForest
# no_tempinc_standard.csv_w5   0.388682     0.42361  0.604588  RandomForest
# tempinc.csv_w1               0.733384     1.64172  0.586544  RandomForest
# tempinc.csv_w3                0.77775     1.68076  0.576712  RandomForest
# tempinc.csv_w5               0.780485     1.69714  0.572587  RandomForest
# tempinc_minmax.csv_w1       0.0304335  0.00271977  0.603496  RandomForest
# tempinc_minmax.csv_w3       0.0303331  0.00270737  0.605303  RandomForest
# tempinc_minmax.csv_w5       0.0301845  0.00270558  0.605565  RandomForest
# tempinc_standard.csv_w1      0.397873    0.406534  0.556457  RandomForest
# tempinc_standard.csv_w3      0.384595     0.40204  0.561361  RandomForest
# tempinc_standard.csv_w5      0.383522    0.408135  0.554711  RandomForest

# %%
model_summ.sort_values(by = 'r_squared', ascending=False)
# Out:
#                                                                      feat_imp  \
# no_tempinc.csv_w1           [0.007185624, 0.006700246, 0.8533451, 0.005470...
# no_tempinc_standard.csv     [0.030535894528414827, 0.03083623724014279, 0....
# tempinc_standard.csv        [0.001598057, 0.0, 0.0026110376, 0.93779457, 0...
# tempinc.csv                 [0.004522228, 0.005455211, 0.82258695, 0.00869...
# tempinc_minmax.csv          [0.0027495276, 0.0, 0.00253314, 0.9097434, 0.0...
# no_tempinc.csv_w3           [0.0025024228, 0.0038228417, 0.93996364, 0.001...
# no_tempinc.csv              [0.010616321, 0.01124595, 0.7321606, 0.0095584...
# tempinc.csv_w1              [0.0075900466, 0.007901227, 0.7488843, 0.00734...
# no_tempinc.csv_w5           [0.0014790962, 0.0026599183, 0.9485154, 0.0009...
# no_tempinc_minmax.csv       [0.04322643208376294, 0.03836253261671352, 0.0...
# tempinc_minmax.csv_w1       [0.004413662, 0.0, 0.004751469, 0.9123705, 0.0...
# tempinc.csv_w3              [0.0025797277, 0.0025970198, 0.9012106, 0.0033...
# no_tempinc.csv              [0.05355123442057005, 0.06843679016391348, 0.1...
# tempinc_minmax.csv_w5       [0.00435395, 0.0, 0.006284555, 0.87035006, 0.0...
# no_tempinc_minmax.csv       [0.0040060766, 0.0, 0.004586884, 0.87501675, 0...
# tempinc.csv_w5              [0.0011364846, 0.0028603063, 0.9541996, 0.0022...
# tempinc_minmax.csv_w3       [0.004866778, 0.0, 0.0061931224, 0.8909109, 0....
# tempinc.csv                 [0.039895780524267094, 0.08058323357366043, 0....
# tempinc_standard.csv_w1     [0.003273646, 0.0, 0.0029930652, 0.9056725, 0....
# no_tempinc_minmax.csv_w3    [0.0487222664168777, 0.04821980686165269, 0.06...
# no_tempinc_standard.csv_w3  [0.034409516668093186, 0.03300392975122114, 0....
# tempinc_minmax.csv_w5       [0.040677857063344446, 0.04192120458573366, 0....
# tempinc_minmax.csv_w3       [0.03772003654643796, 0.038747950147682765, 0....
# no_tempinc_standard.csv_w5  [0.03333652636459231, 0.034216883086092095, 0....
# tempinc_minmax.csv_w1       [0.03146586974664891, 0.031827204166816864, 0....
# tempinc_standard.csv        [0.03007864570106209, 0.03209287312142463, 0.0...
# tempinc_minmax.csv          [0.022897365284291933, 0.028533459585647545, 0...
# no_tempinc_standard.csv     [0.002098261, 0.0, 0.004272864, 0.9188961, 0.0...
# no_tempinc_minmax.csv_w1    [0.047481296610358936, 0.03891007692388185, 0....
# tempinc.csv_w1              [0.06211789935281993, 0.05450461182465864, 0.0...
# tempinc.csv_w3              [0.07911495750478056, 0.05667097289151612, 0.1...
# no_tempinc_standard.csv_w1  [0.02896578599553321, 0.027535279905785037, 0....
# tempinc.csv_w5              [0.08640134208072398, 0.060567478657367196, 0....
# no_tempinc_minmax.csv_w5    [0.04284319623742259, 0.04506262317146338, 0.0...
# tempinc_standard.csv_w3     [0.04319988531232704, 0.04070706213567532, 0.0...
# no_tempinc_standard.csv_w1  [0.0023506477, 0.0, 0.0030747093, 0.9010628, 0...
# tempinc_standard.csv_w1     [0.02994804844824547, 0.028969605012624636, 0....
# tempinc_standard.csv_w5     [0.04843419534398834, 0.043000194886327545, 0....
# tempinc_standard.csv_w3     [0.003279502, 0.0, 0.0029794828, 0.9046678, 0....
# tempinc_standard.csv_w5     [0.002741754, 0.0, 0.0026369556, 0.896059, 0.0...
# no_tempinc.csv_w1           [0.04529165319750909, 0.09796988122629229, 0.0...
# no_tempinc.csv_w3           [0.039650507391347886, 0.1335544420800936, 0.1...
# no_tempinc.csv_w5           [0.03987915830898582, 0.1430823449955169, 0.08...
# no_tempinc_minmax.csv_w1    [0.0035745816, 0.0, 0.0040917215, 0.9350306, 0...
# no_tempinc_standard.csv_w3  [0.0023448896, 0.0, 0.002684519, 0.8925107, 0....
# no_tempinc_minmax.csv_w3    [0.0044359653, 0.0, 0.0046973457, 0.9227859, 0...
# no_tempinc_standard.csv_w5  [0.0021580537, 0.0, 0.002546614, 0.8897561, 0....
# no_tempinc_minmax.csv_w5    [0.005682336, 0.0, 0.005929909, 0.91001, 0.002...
#
#                                   mae         mse r_squared         Model
# no_tempinc.csv_w1            0.607769    0.975468  0.738696           XGB
# no_tempinc_standard.csv      0.361494     0.25033  0.711342  RandomForest
# tempinc_standard.csv         0.318485    0.305168  0.693136           XGB
# tempinc.csv                  0.655323     1.25939  0.687694           XGB
# tempinc_minmax.csv           0.028061  0.00177771  0.687364           XGB
# no_tempinc.csv_w3            0.668146     1.18457  0.682683           XGB
# no_tempinc.csv               0.614908     1.27309  0.675926           XGB
# tempinc.csv_w1               0.672679     1.39695  0.675303           XGB
# no_tempinc.csv_w5            0.683214     1.24799  0.665694           XGB
# no_tempinc_minmax.csv       0.0323015  0.00217952  0.661565  RandomForest
# tempinc_minmax.csv_w1       0.0285944  0.00215622  0.651132           XGB
# tempinc.csv_w3               0.711012      1.5411  0.641797           XGB
# no_tempinc.csv               0.725192      1.2689  0.639824  RandomForest
# tempinc_minmax.csv_w5       0.0294492  0.00223648  0.638146           XGB
# no_tempinc_minmax.csv       0.0294134  0.00268545  0.630875           XGB
# tempinc.csv_w5               0.733331     1.60846   0.62614           XGB
# tempinc_minmax.csv_w3       0.0287068   0.0023313  0.622804           XGB
# tempinc.csv                  0.739957     1.16688  0.620966  RandomForest
# tempinc_standard.csv_w1       0.36674    0.399304  0.612084           XGB
# no_tempinc_minmax.csv_w3    0.0324501  0.00251928  0.611181  RandomForest
# no_tempinc_standard.csv_w3   0.383734    0.421223  0.606816  RandomForest
# tempinc_minmax.csv_w5       0.0301845  0.00270558  0.605565  RandomForest
# tempinc_minmax.csv_w3       0.0303331  0.00270737  0.605303  RandomForest
# no_tempinc_standard.csv_w5   0.388682     0.42361  0.604588  RandomForest
# tempinc_minmax.csv_w1       0.0304335  0.00271977  0.603496  RandomForest
# tempinc_standard.csv         0.394865    0.381709  0.600363  RandomForest
# tempinc_minmax.csv          0.0317864  0.00251445  0.600354  RandomForest
# no_tempinc_standard.csv       0.37335    0.378409   0.59606           XGB
# no_tempinc_minmax.csv_w1    0.0334954  0.00262365  0.595074  RandomForest
# tempinc.csv_w1               0.733384     1.64172  0.586544  RandomForest
# tempinc.csv_w3                0.77775     1.68076  0.576712  RandomForest
# no_tempinc_standard.csv_w1    0.40604    0.457309  0.573131  RandomForest
# tempinc.csv_w5               0.780485     1.69714  0.572587  RandomForest
# no_tempinc_minmax.csv_w5    0.0331648  0.00283798  0.561994  RandomForest
# tempinc_standard.csv_w3      0.384595     0.40204  0.561361  RandomForest
# no_tempinc_standard.csv_w1   0.376982     0.42907   0.55927           XGB
# tempinc_standard.csv_w1      0.397873    0.406534  0.556457  RandomForest
# tempinc_standard.csv_w5      0.383522    0.408135  0.554711  RandomForest
# tempinc_standard.csv_w3       0.35501    0.458606  0.554473           XGB
# tempinc_standard.csv_w5      0.363797    0.477566  0.536054           XGB
# no_tempinc.csv_w1            0.815191     1.74302  0.517908  RandomForest
# no_tempinc.csv_w3            0.859842     1.83966  0.491178  RandomForest
# no_tempinc.csv_w5            0.880001     1.85963  0.485655  RandomForest
# no_tempinc_minmax.csv_w1    0.0312823  0.00318844  0.475876           XGB
# no_tempinc_standard.csv_w3   0.409119    0.666305  0.315587           XGB
# no_tempinc_minmax.csv_w3     0.032836  0.00446178  0.266563           XGB
# no_tempinc_standard.csv_w5   0.421731    0.767217  0.211934           XGB
# no_tempinc_minmax.csv_w5    0.0330172  0.00487382  0.198831           XGB
